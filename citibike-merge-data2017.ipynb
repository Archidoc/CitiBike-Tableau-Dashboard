# %%
# add dependencies
import pandas as pd

# %%
# load downloaded csv files
# let's load a full year of data. the closest is 2017. I also include quarters
m1_csv="data/JC-201701-citibike-tripdata.csv"
m2_csv="data/JC-201702-citibike-tripdata.csv"
m3_csv="data/JC-201703-citibike-tripdata.csv"
m4_csv="data/JC-201704-citibike-tripdata.csv"
m5_csv="data/JC-201705-citibike-tripdata.csv"
m6_csv="data/JC-201706-citibike-tripdata.csv"
m7_csv="data/JC-201707-citibike-tripdata.csv"
m8_csv="data/JC-201708-citibike-tripdata.csv"
m9_csv="data/JC-201709-citibike-tripdata.csv"
m10_csv="data/JC-201710-citibike-tripdata.csv"
m11_csv="data/JC-201711-citibike-tripdata.csv"
m12_csv="data/JC-201712-citibike-tripdata.csv"

q1_csv = "data/data-2017-q1.csv"
q2_csv = "data/data-2017-q2.csv"
q3_csv = "data/data-2017-q3.csv"
q4_csv = "data/data-2017-q4.csv"

m1_data = pd.read_csv(m1_csv)
m2_data = pd.read_csv(m2_csv)
m3_data = pd.read_csv(m3_csv)
m4_data = pd.read_csv(m4_csv)
m5_data = pd.read_csv(m5_csv)
m6_data = pd.read_csv(m6_csv)
m7_data = pd.read_csv(m7_csv)
m8_data = pd.read_csv(m8_csv)
m9_data = pd.read_csv(m9_csv)
m10_data = pd.read_csv(m10_csv)
m11_data = pd.read_csv(m11_csv)
m12_data = pd.read_csv(m12_csv)

q1_data = pd.read_csv(q1_csv)
q2_data = pd.read_csv(q2_csv)
q3_data = pd.read_csv(q3_csv)
q4_data = pd.read_csv(q4_csv)

# %%
m3_data.columns
# Out:
# Index(['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID',
#        'Start Station Name', 'Start Station Latitude',
#        'Start Station Longitude', 'End Station ID', 'End Station Name',
#        'End Station Latitude', 'End Station Longitude', 'Bike ID', 'User Type',
#        'Birth Year', 'Gender'],
#       dtype='object')

# %%
m4_data.columns
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
# merge dataset 1
dataset_1A = [m1_data, m2_data, m3_data]
df1A=pd.concat(dataset_1A)
df1A.head()
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0            148  2017-01-01 00:21:32  2017-01-01 00:24:01              3276
# 1           1283  2017-01-01 00:24:35  2017-01-01 00:45:58              3183
# 2            372  2017-01-01 00:38:19  2017-01-01 00:44:31              3183
# 3           1513  2017-01-01 00:38:37  2017-01-01 01:03:50              3194
# 4            639  2017-01-01 01:47:52  2017-01-01 01:58:31              3183
#
#   Start Station Name  Start Station Latitude  Start Station Longitude  \
# 0   Marin Light Rail               40.714584               -74.042817
# 1     Exchange Place               40.716247               -74.033459
# 2     Exchange Place               40.716247               -74.033459
# 3    McGinley Square               40.725340               -74.067622
# 4     Exchange Place               40.716247               -74.033459
#
#    End Station ID     End Station Name  End Station Latitude  \
# ...

# %%
df1A.count()
# Out:
# Trip Duration              39153
# Start Time                 39153
# Stop Time                  39153
# Start Station ID           39153
# Start Station Name         39153
# Start Station Latitude     39153
# Start Station Longitude    39153
# End Station ID             39153
# End Station Name           39153
# End Station Latitude       39153
# End Station Longitude      39153
# Bike ID                    39153
# User Type                  39036
# Birth Year                 37448
# Gender                     39153
# dtype: int64

# %%
# merge dataset 1
dataset_1B = [m4_data, m5_data, m6_data, m7_data, m8_data, m9_data, m10_data, m11_data, m12_data]
df1B=pd.concat(dataset_1B)
df1B.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           252  2017-04-01 00:14:36  2017-04-01 00:18:48              3186
# 1           452  2017-04-01 00:15:47  2017-04-01 00:23:20              3203
# 2           465  2017-04-01 00:46:27  2017-04-01 00:54:13              3271
# 3           417  2017-04-01 00:47:15  2017-04-01 00:54:13              3271
# 4           391  2017-04-01 01:13:12  2017-04-01 01:19:44              3183
#
#     start station name  start station latitude  start station longitude  \
# 0        Grove St PATH               40.719586               -74.043117
# 1        Hamilton Park               40.727596               -74.044247
# 2  Danforth Light Rail               40.692640               -74.088012
# 3  Danforth Light Rail               40.692640               -74.088012
# 4       Exchange Place               40.716247               -74.033459
#
#    end station id end station name  end station latitude  \
# ...

# %%
# rename columns of df4 to df12 before merge with df1 to df3
df1B.rename(columns={'tripduration':'Trip Duration', 'starttime':'Start Time', 'stoptime':'Stop Time', 'start station id':'Start Station ID', 'start station name':'Start Station Name', 'start station latitude':'Start Station Latitude', 'start station longitude':'Start Station Longitude', 'end station id':'End Station ID', 'end station name':'End Station Name', 'end station latitude':'End Station Latitude', 'end station longitude':'End Station Longitude', 'bikeid':'Bike ID', 'usertype':'User Type', 'birth year':'Birth Year', 'gender':'Gender'}, inplace=True)
df1B.columns
# Out:
# Index(['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID',
#        'Start Station Name', 'Start Station Latitude',
#        'Start Station Longitude', 'End Station ID', 'End Station Name',
#        'End Station Latitude', 'End Station Longitude', 'Bike ID', 'User Type',
#        'Birth Year', 'Gender'],
#       dtype='object')

# %%
df1B.head()
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0            252  2017-04-01 00:14:36  2017-04-01 00:18:48              3186
# 1            452  2017-04-01 00:15:47  2017-04-01 00:23:20              3203
# 2            465  2017-04-01 00:46:27  2017-04-01 00:54:13              3271
# 3            417  2017-04-01 00:47:15  2017-04-01 00:54:13              3271
# 4            391  2017-04-01 01:13:12  2017-04-01 01:19:44              3183
#
#     Start Station Name  Start Station Latitude  Start Station Longitude  \
# 0        Grove St PATH               40.719586               -74.043117
# 1        Hamilton Park               40.727596               -74.044247
# 2  Danforth Light Rail               40.692640               -74.088012
# 3  Danforth Light Rail               40.692640               -74.088012
# 4       Exchange Place               40.716247               -74.033459
#
#    End Station ID End Station Name  End Station Latitude  \
# ...

# %%
df1B.count()
# Out:
# Trip Duration              255775
# Start Time                 255775
# Stop Time                  255775
# Start Station ID           255775
# Start Station Name         255775
# Start Station Latitude     255775
# Start Station Longitude    255775
# End Station ID             255775
# End Station Name           255775
# End Station Latitude       255775
# End Station Longitude      255775
# Bike ID                    255775
# User Type                  255775
# Birth Year                 237865
# Gender                     255775
# dtype: int64

# %%
# merge df1A and df1B dataset
dataset_merged = [df1A, df1B]
df1=pd.concat(dataset_merged)
df1
# Out:
#        Trip Duration           Start Time            Stop Time  \
# 0                148  2017-01-01 00:21:32  2017-01-01 00:24:01
# 1               1283  2017-01-01 00:24:35  2017-01-01 00:45:58
# 2                372  2017-01-01 00:38:19  2017-01-01 00:44:31
# 3               1513  2017-01-01 00:38:37  2017-01-01 01:03:50
# 4                639  2017-01-01 01:47:52  2017-01-01 01:58:31
# 5                258  2017-01-01 01:56:29  2017-01-01 02:00:48
# 6                663  2017-01-01 02:12:34  2017-01-01 02:23:38
# 7                567  2017-01-01 02:15:52  2017-01-01 02:25:20
# 8                551  2017-01-01 02:16:03  2017-01-01 02:25:15
# 9                573  2017-01-01 02:22:17  2017-01-01 02:31:50
# 10               535  2017-01-01 02:22:59  2017-01-01 02:31:55
# 11               224  2017-01-01 02:23:53  2017-01-01 02:27:37
# 12              1699  2017-01-01 02:33:12  2017-01-01 03:01:31
# 13               350  2017-01-01 02:37:31  2017-01-01 02:43:22
# ...

# %%
# verify unique columns names
df1.columns
# Out:
# Index(['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID',
#        'Start Station Name', 'Start Station Latitude',
#        'Start Station Longitude', 'End Station ID', 'End Station Name',
#        'End Station Latitude', 'End Station Longitude', 'Bike ID', 'User Type',
#        'Birth Year', 'Gender'],
#       dtype='object')

# %%
# count total
df1.count()
# Out:
# Trip Duration              294928
# Start Time                 294928
# Stop Time                  294928
# Start Station ID           294928
# Start Station Name         294928
# Start Station Latitude     294928
# Start Station Longitude    294928
# End Station ID             294928
# End Station Name           294928
# End Station Latitude       294928
# End Station Longitude      294928
# Bike ID                    294928
# User Type                  294811
# Birth Year                 275313
# Gender                     294928
# dtype: int64

# %%
# merge dataset 2
dataset_2 = [q1_data, q2_data, q3_data, q4_data]
df2=pd.concat(dataset_2)
df2.head()
# Out:
#      Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  1/1/17                                              16009
# 1  1/2/17                                               8921
# 2  1/3/17                                              14198
# 3  1/4/17                                              34039
# 4  1/5/17                                              28393
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                        50761
# 1                                        21545
# 2                                        25879
# 3                                        69966
# 4                                        52446
#
#    Total Annual Members (All Time)  \
# 0                           206624
# 1                           206675
# 2                           206728
# 3                           206778
# 4                           206845
#
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# ...

# %%
df2.count()
# Out:
# Date                                                  365
# Trips over the past 24-hours (midnight to 11:59pm)    365
# Miles traveled today (midnight to 11:59 pm)           365
# Total Annual Members (All Time)                       365
# 24-Hour Passes Purchased (midnight to 11:59 pm)       365
# 3-Day Passes Purchased (midnight to 11:59 pm)         365
# dtype: int64

# %%
# export to csv files
df1.to_csv("concat_data_2017.csv")
df2.to_csv("concat_quarterdata_2017.csv")
